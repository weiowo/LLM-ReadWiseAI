# %%
import pandas as pd

books = pd.read_csv("books_cleaned.csv")

# %%
books["categories"].value_counts().reset_index()

# %%
books["categories"].value_counts().reset_index().query("count > 50")

# %%
books[books["categories"] == "Juvenile Fiction"]
# Out:
#              isbn13      isbn10  \
# 30    9780006646006  000664600X
# 79    9780020442608  0020442602
# 85    9780030547744  0030547741
# 86    9780060000141  0060000147
# 87    9780060001537  0060001534
# ...             ...         ...
# 4845  9781590385814  1590385810
# 4930  9781596792500  1596792507
# 4942  9781599900056  159990005X
# 5010  9781844580514  1844580512
# 5157  9781932416374  1932416374
#
#                                                   title  \
# 30                                   Ocean Star Express
# 79                       The voyage of the Dawn Treader
# 85                             Where the Red Fern Grows
# 86                                       Poppy's Return
# 87                                    Diary of a Spider
# ...                                                 ...
# 4845                                         Fablehaven
# 4930  Sherlock Holmes and the Case of the Hound of t...
# 4942                                    The Drift House
# 5010                               Attack of the Jaguar
# 5157                The Very Persistent Gappers of Frip
#
#                                   authors        categories  \
# 30               Mark Haddon;Peter Sutton  Juvenile Fiction
# 79                    Clive Staples Lewis  Juvenile Fiction
# 85                           Wilson Rawls  Juvenile Fiction
# 86                                    Avi  Juvenile Fiction
# 87                          Doreen Cronin  Juvenile Fiction
# ...                                   ...               ...
# 4845                         Brandon Mull  Juvenile Fiction
# 4930  Arthur Conan Doyle;Malvina G. Vogel  Juvenile Fiction
# 4942                            Dale Peck  Juvenile Fiction
# 5010                         M. A. Harvey  Juvenile Fiction
# 5157           George Saunders;Lane Smith  Juvenile Fiction
#
#                                               thumbnail  \
# 30    http://books.google.com/books/content?id=I2QZA...
# 79    http://books.google.com/books/content?id=fDD3C...
# 85    http://books.google.com/books/content?id=IHpRw...
# 86    http://books.google.com/books/content?id=XbcMJ...
# 87    http://books.google.com/books/content?id=UWvZo...
# ...                                                 ...
# 4845  http://books.google.com/books/content?id=tbVIP...
# 4930  http://books.google.com/books/content?id=EWgWP...
# 4942  http://books.google.com/books/content?id=kbwPY...
# 5010  http://books.google.com/books/content?id=3HUdt...
# 5157  http://books.google.com/books/content?id=xYJOP...
#
#                                             description  published_year  \
# 30    Joe and his parents are enjoying a summer holi...          2002.0
# 79    The "Dawn Treader" is the first ship Narnia ha...          1970.0
# 85    A young boy living in the Ozarks achieves his ...          2000.0
# 86    There's trouble at Gray House, the girlhood ho...          2006.0
# 87    This is the diary ... of a spider. But don't b...          2005.0
# ...                                                 ...             ...
# 4845  When Kendra and Seth go to stay at their grand...          2006.0
# 4930  Sherlock Holmes and Dr. Watson travel to the b...          2005.0
# 4942  Sent to stay with their uncle in a ship-like h...          2006.0
# 5010  This training manual for operatives of Xtreme ...          2004.0
# 5157  A novel set in the seaside village of Frip fol...          2006.0
#
#       average_rating  num_pages  ratings_count  \
# 30              3.50       32.0            1.0
# 79              4.09      216.0         2869.0
# 85              4.37      288.0           95.0
# 86              3.99      256.0         1086.0
# 87              4.25       40.0         7903.0
# ...              ...        ...            ...
# 4845            4.09      351.0       111896.0
# 4930            4.51      237.0           28.0
# 4942            3.64      437.0          595.0
# 5010            3.40      125.0            4.0
# 5157            4.11       84.0         2317.0
#
#                                      title_and_subtitle  \
# 30                                   Ocean Star Express
# 79                       The voyage of the Dawn Treader
# 85    Where the Red Fern Grows: The Story of Two Dog...
# 86                                       Poppy's Return
# 87                                    Diary of a Spider
# ...                                                 ...
# 4845                                         Fablehaven
# 4930  Sherlock Holmes and the Case of the Hound of t...
# 4942                  The Drift House: The First Voyage
# 5010                               Attack of the Jaguar
# 5157                The Very Persistent Gappers of Frip
#
#                                      tagged_description
# 30    9780006646006 Joe and his parents are enjoying...
# 79    9780020442608 The "Dawn Treader" is the first ...
# 85    9780030547744 A young boy living in the Ozarks...
# 86    9780060000141 There's trouble at Gray House, t...
# 87    9780060001537 This is the diary ... of a spide...
# ...                                                 ...
# 4845  9781590385814 When Kendra and Seth go to stay ...
# 4930  9781596792500 Sherlock Holmes and Dr. Watson t...
# 4942  9781599900056 Sent to stay with their uncle in...
# 5010  9781844580514 This training manual for operati...
# 5157  9781932416374 A novel set in the seaside villa...
#
# [390 rows x 13 columns]

# %%
# %pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.51.3-py3-none-any.whl (10.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 1.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyyaml>=5.1 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: numpy>=1.17 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers) (0.30.2)
# Collecting safetensors>=0.4.3
#   Downloading safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl (418 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.4/418.4 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: tqdm>=4.27 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers) (0.21.1)
# Requirement already satisfied: filelock in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: packaging>=20.0 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers) (24.2)
# Requirement already satisfied: requests in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests->transformers) (3.10)
# Installing collected packages: safetensors, transformers
# Successfully installed safetensors-0.5.3 transformers-4.51.3
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (2.6.0)
# Collecting torchvision
#   Downloading torchvision-0.21.0-cp310-cp310-macosx_11_0_arm64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 2.0 MB/s eta 0:00:00a 0:00:01
# Collecting torchaudio
#   Downloading torchaudio-2.6.0-cp310-cp310-macosx_11_0_arm64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 1.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jinja2 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: filelock in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch) (3.18.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: networkx in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: fsspec in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch) (4.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torchvision) (11.2.1)
# Requirement already satisfied: numpy in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Installing collected packages: torchvision, torchaudio
# Successfully installed torchaudio-2.6.0 torchvision-0.21.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

print(torch.__version__)
print("MPS available:", torch.backends.mps.is_available())
# Out:
# 2.6.0
# MPS available: True

# %%
# %pip install torch --upgrade --no-cache-dir --index-url https://download.pytorch.org/whl/nightly/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/nightly/cpu
# Requirement already satisfied: torch in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (2.6.0)
# Collecting torch
#   Obtaining dependency information for torch from https://download.pytorch.org/whl/nightly/cpu/torch-2.8.0.dev20250414-cp310-none-macosx_11_0_arm64.whl.metadata
#   Downloading https://download.pytorch.org/whl/nightly/cpu/torch-2.8.0.dev20250414-cp310-none-macosx_11_0_arm64.whl.metadata (28 kB)
# Requirement already satisfied: filelock in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch) (3.18.0)
# Requirement already satisfied: networkx in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch) (3.1.6)
# Collecting sympy>=1.13.3
#   Downloading https://download.pytorch.org/whl/nightly/sympy-1.13.3-py3-none-any.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 1.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch) (4.13.1)
# Requirement already satisfied: fsspec in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Downloading https://download.pytorch.org/whl/nightly/cpu/torch-2.8.0.dev20250414-cp310-none-macosx_11_0_arm64.whl (70.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 MB 1.8 MB/s eta 0:00:0000:0100:02
# Downloading https://download.pytorch.org/whl/nightly/cpu/torch-2.8.0.dev20250414-cp310-none-macosx_11_0_arm64.whl (70.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 MB 2.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: sympy, torch
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0
#     Uninstalling torch-2.6.0:
#       Successfully uninstalled torch-2.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.21.0 requires torch==2.6.0, but you have torch 2.8.0.dev20250414 which is incompatible.
# torchaudio 2.6.0 requires torch==2.6.0, but you have torch 2.8.0.dev20250414 which is incompatible.
# Successfully installed sympy-1.13.3 torch-2.8.0.dev20250414
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install backports.lzma
# Out:
# Collecting backports.lzma
#   Downloading backports.lzma-0.0.14.tar.gz (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 819.7 kB/s eta 0:00:00 0:00:01
#   Preparing metadata (setup.py) ... done
# Installing collected packages: backports.lzma
#   DEPRECATION: backports.lzma is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for backports.lzma ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for backports.lzma did not run successfully.
#   │ exit code: 1
#   ╰─> [23 lines of output]
#       This is backports.lzma version 0.0.14
#       running install
#       /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-13.4-arm64-cpython-310
#       creating build/lib.macosx-13.4-arm64-cpython-310/backports
#       copying backports/__init__.py -> build/lib.macosx-13.4-arm64-cpython-310/backports
#       creating build/lib.macosx-13.4-arm64-cpython-310/backports/lzma
#       copying backports/lzma/__init__.py -> build/lib.macosx-13.4-arm64-cpython-310/backports/lzma
#       running build_ext
#       building 'backports.lzma._lzma' extension
#       creating build/temp.macosx-13.4-arm64-cpython-310
#       creating build/temp.macosx-13.4-arm64-cpython-310/backports
#       creating build/temp.macosx-13.4-arm64-cpython-310/backports/lzma
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/Users/weiwei/.pyenv/versions/3.10.13/include -I/Users/weiwei/include -I/opt/local/include -I/usr/local/include -I/Users/weiwei/.pyenv/versions/3.10.13/include/python3.10 -c backports/lzma/_lzmamodule.c -o build/temp.macosx-13.4-arm64-cpython-310/backports/lzma/_lzmamodule.o
#       backports/lzma/_lzmamodule.c:115:10: fatal error: 'lzma.h' file not found
#       #include <lzma.h>
#                ^~~~~~~~
#       1 error generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> backports.lzma
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cpu/torch-2.6.0-cp310-none-macosx_11_0_arm64.whl.metadata (28 kB)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cpu/torchvision-0.21.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cpu/torchaudio-2.6.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch) (4.13.1)
# Requirement already satisfied: networkx in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch) (2025.3.2)
# Collecting sympy==1.13.1 (from torch)
#   Downloading https://download.pytorch.org/whl/sympy-1.13.1-py3-none-any.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 2.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torchvision) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/weiwei/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Downloading https://download.pytorch.org/whl/cpu/torch-2.6.0-cp310-none-macosx_11_0_arm64.whl (66.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 MB 1.5 MB/s eta 0:00:0000:0100:020m
# Downloading https://download.pytorch.org/whl/cpu/torchvision-0.21.0-cp310-cp310-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 2.0 MB/s eta 0:00:00a 0:00:01
# Downloading https://download.pytorch.org/whl/cpu/torchaudio-2.6.0-cp310-cp310-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 2.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: sympy, torch, torchvision, torchaudio
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.3
#     Uninstalling sympy-1.13.3:
#       Successfully uninstalled sympy-1.13.3
# Successfully installed sympy-1.13.1 torch-2.6.0 torchaudio-2.6.0 torchvision-0.21.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import pipeline

fiction_categories = ["Fiction", "Nonfiction"]

pipe = pipeline("zero-shot-classification",
                model="facebook/bart-large-mnli")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/transformers/utils/import_utils.py:1967, in _LazyModule._get_module(self, module_name)
#    1966 try:
# -> 1967     return importlib.import_module("." + module_name, self.__name__)
#    1968 except Exception as e:
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/transformers/pipelines/__init__.py:26
#      25 from ..feature_extraction_utils import PreTrainedFeatureExtractor
# ---> 26 from ..image_processing_utils import BaseImageProcessor
#      27 from ..models.auto.configuration_auto import AutoConfig
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/transformers/image_processing_utils.py:22
#      21 from .image_processing_base import BatchFeature, ImageProcessingMixin
# ---> 22 from .image_transforms import center_crop, normalize, rescale
#      23 from .image_utils import ChannelDimension, get_image_size
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/transformers/image_transforms.py:21
#      19 import numpy as np
# ---> 21 from .image_utils import (
#      22     ChannelDimension,
#      23     ImageInput,
#      24     get_channel_dimension_axis,
#      25     get_image_size,
#      26     infer_channel_dimension_format,
#      27 )
#      28 from .utils import ExplicitEnum, TensorType, is_jax_tensor, is_tf_tensor, is_torch_tensor
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/transformers/image_utils.py:64
#      63 if is_torchvision_available():
# ---> 64     from torchvision import io as torchvision_io
#      65     from torchvision.transforms import InterpolationMode
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/torchvision/__init__.py:10
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/torchvision/_meta_registrations.py:26
#      22     return wrapper
#      25 @register_meta("roi_align")
# ---> 26 def meta_roi_align(input, rois, spatial_scale, pooled_height, pooled_width, sampling_ratio, aligned):
#      27     torch._check(rois.size(1) == 5, lambda: "rois must have shape as Tensor[K, 5]")
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/torchvision/_meta_registrations.py:18, in register_meta.<locals>.wrapper(fn)
#      17 def wrapper(fn):
# ---> 18     if torchvision.extension._has_ops():
#      19         get_meta_lib().impl(getattr(getattr(torch.ops.torchvision, op_name), overload_name), fn)
#
# AttributeError: partially initialized module 'torchvision' has no attribute 'extension' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from transformers import pipeline
#       3 fiction_categories = ["Fiction", "Nonfiction"]
#       5 pipe = pipeline("zero-shot-classification",
#       6                 model="facebook/bart-large-mnli")
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/transformers/utils/import_utils.py:1955, in _LazyModule.__getattr__(self, name)
#    1953     value = Placeholder
#    1954 elif name in self._class_to_module.keys():
# -> 1955     module = self._get_module(self._class_to_module[name])
#    1956     value = getattr(module, name)
#    1957 elif name in self._modules:
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/transformers/utils/import_utils.py:1969, in _LazyModule._get_module(self, module_name)
#    1967     return importlib.import_module("." + module_name, self.__name__)
#    1968 except Exception as e:
# -> 1969     raise RuntimeError(
#    1970         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1971         f" traceback):\n{e}"
#    1972     ) from e
#
# RuntimeError: Failed to import transformers.pipelines because of the following error (look up to see its traceback):
# partially initialized module 'torchvision' has no attribute 'extension' (most likely due to a circular import)
